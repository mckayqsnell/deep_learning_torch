# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/porterjenkins/byu-cs474/blob/master/lab5_generalization.ipynb)

# %% [markdown]
# # Lab 5: Measuring Performance

# %% [markdown]
# ## Objectives
#
#
# *   Understand how to accurately measure generalization performance of deep networks
# *   Gain intuition into the bias-variance trade-off and the double descent phenomenon
# *   Investigate properties of high dimensional spaces and better understand the ''curse of dimensionality''

# %% [markdown]
# ## Deliverable
#
# You will turn in a completed version of notebook to Canvas/Learning Suite.  In various places you will see the words "TO DO". Follow the instructions at these places and write code to complete the instructions

# %% [markdown]
# ## Notes
# You will not need a GPU instance for this lab

# %% [markdown]
# ## Q1) Understanding Generalization
#
# In this question, we will use the MNIST1D dataset (https://github.com/greydanus/mnist1d) to reproduce Figure 8.2 from Prince.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-prs605rg
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-prs605rg
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post16) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post16) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post16) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post16) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post16) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.16.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14625 sha256=04dc59c2838849b3ac3ad73ac35b0337ac05e7ed1ffe124bd68f53e579d08844
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lzynv7bt/wheels/41/95/55/45fcf7d38cfa97e35682da6c5017d4513729131326ce935371
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code. The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
# !mkdir ./sample_data

args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./sample_data/mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# mkdir: cannot create directory ‘./sample_data’: File exists
# Did or could not load data from ./sample_data/mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions

# %% [markdown]
# ### Part 1.a)

# %% [markdown]
# **TODO:** Define a PyTorch model with two hidden layers of size 100 And ReLU activations between them

# %%
# Your code here (see Figure 7.8 of book for help)
# create model with two hidden layers
model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

# %% [markdown]
# **TODO:** Initialize the parameters with He initialization

# %%
def weights_init(layer_in):
    # TODO: Replace this line (see figure 7.8 of Prince for help)
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('long'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
def train_model(model, data_loader, n_epoch=50):

    # Initialize model weights
    model.apply(weights_init)

    # store the loss and the % correct at each epoch
    losses_train = np.zeros((n_epoch))
    errors_train = np.zeros((n_epoch))
    losses_test = np.zeros((n_epoch))
    errors_test = np.zeros((n_epoch))

    # choose cross entropy loss function (equation 5.24)
    loss_function = torch.nn.CrossEntropyLoss()
    # construct SGD optimizer and initialize learning rate and momentum
    optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
    # object that decreases learning rate by half every 10 epochs
    scheduler = StepLR(optimizer, step_size=10, gamma=0.5)


    for epoch in range(n_epoch):
      # loop over batches
      for i, batch in enumerate(data_loader):
        # retrieve inputs and labels for this batch
        x_batch, y_batch = batch
        # zero the parameter gradients
        optimizer.zero_grad()
        # forward pass -- calculate model output
        pred = model(x_batch)
        # compute the loss
        loss = loss_function(pred, y_batch)
        # backward pass
        loss.backward()
        # SGD update
        optimizer.step()

      # Run whole dataset to get statistics -- normally wouldn't do this
      pred_train = model(x_train)
      pred_test = model(x_test)
      _, predicted_train_class = torch.max(pred_train.data, 1)
      _, predicted_test_class = torch.max(pred_test.data, 1)
      errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
      errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
      losses_train[epoch] = loss_function(pred_train, y_train).item()
      losses_test[epoch]= loss_function(pred_test, y_test).item()
      print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

      # tell scheduler to consider updating learning rate
      scheduler.step()

    return errors_train, errors_test, losses_train, losses_test

# %%
def plot_results(errors_train, errors_test, losses_train, losses_test, n_epoch=50):

    # Plot the results
    fig, ax = plt.subplots()
    ax.plot(errors_train,'r-',label='train')
    ax.plot(errors_test,'b-',label='test')
    ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
    ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
    ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
    ax.legend()
    plt.show()

    # Plot the results
    fig, ax = plt.subplots()
    ax.plot(losses_train,'r-',label='train')
    ax.plot(losses_test,'b-',label='test')
    ax.set_xlim(0,n_epoch)
    ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
    ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
    ax.legend()
    plt.show()

# %% [markdown]
# **TODO:** Train your model for 50 epochs

# %%
errors_train, errors_test, losses_train, losses_test = train_model(model, data_loader, n_epoch=50)
# Out:
# Epoch     0, train loss 1.632575, train error 64.95,  test loss 1.680933, test error 69.30
# Epoch     1, train loss 1.376670, train error 52.28,  test loss 1.495164, test error 60.10
# Epoch     2, train loss 1.201371, train error 44.45,  test loss 1.373701, test error 53.60
# Epoch     3, train loss 1.023635, train error 36.42,  test loss 1.268086, test error 50.00
# Epoch     4, train loss 0.906872, train error 33.20,  test loss 1.210519, test error 47.20
# Epoch     5, train loss 0.804962, train error 29.12,  test loss 1.194418, test error 46.10
# Epoch     6, train loss 0.749918, train error 27.32,  test loss 1.179939, test error 44.70
# Epoch     7, train loss 0.645198, train error 22.22,  test loss 1.120524, test error 41.90
# Epoch     8, train loss 0.613583, train error 21.57,  test loss 1.130004, test error 41.20
# Epoch     9, train loss 0.528910, train error 17.53,  test loss 1.155562, test error 42.60
# Epoch    10, train loss 0.423895, train error 12.68,  test loss 1.067074, test error 38.30
# Epoch    11, train loss 0.388929, train error 11.12,  test loss 1.082639, test error 38.50
# Epoch    12, train loss 0.354569, train error 9.35,  test loss 1.074239, test error 37.00
# Epoch    13, train loss 0.336932, train error 9.25,  test loss 1.119726, test error 38.40
# Epoch    14, train loss 0.305278, train error 7.78,  test loss 1.127365, test error 38.60
# Epoch    15, train loss 0.278756, train error 6.95,  test loss 1.134800, test error 37.20
# Epoch    16, train loss 0.248649, train error 5.07,  test loss 1.119628, test error 36.10
# Epoch    17, train loss 0.231674, train error 4.75,  test loss 1.186608, test error 38.00
# Epoch    18, train loss 0.218164, train error 4.85,  test loss 1.191646, test error 38.80
# Epoch    19, train loss 0.197931, train error 3.80,  test loss 1.229747, test error 36.40
# Epoch    20, train loss 0.166339, train error 2.45,  test loss 1.190759, test error 36.80
# Epoch    21, train loss 0.162904, train error 2.43,  test loss 1.222790, test error 37.30
# Epoch    22, train loss 0.148965, train error 1.93,  test loss 1.216017, test error 37.00
# Epoch    23, train loss 0.139727, train error 1.53,  test loss 1.231101, test error 37.00
# Epoch    24, train loss 0.133098, train error 1.35,  test loss 1.244314, test error 37.30
# Epoch    25, train loss 0.127433, train error 1.20,  test loss 1.245458, test error 36.40
# Epoch    26, train loss 0.119670, train error 1.00,  test loss 1.265232, test error 36.80
# Epoch    27, train loss 0.116180, train error 1.05,  test loss 1.281725, test error 37.40
# Epoch    28, train loss 0.110152, train error 0.88,  test loss 1.291543, test error 38.00
# Epoch    29, train loss 0.105781, train error 0.72,  test loss 1.294816, test error 37.60
# Epoch    30, train loss 0.099927, train error 0.65,  test loss 1.300820, test error 37.50
# Epoch    31, train loss 0.096058, train error 0.57,  test loss 1.299376, test error 37.40
# Epoch    32, train loss 0.094538, train error 0.47,  test loss 1.312086, test error 37.80
# Epoch    33, train loss 0.092171, train error 0.47,  test loss 1.319334, test error 37.60
# Epoch    34, train loss 0.089684, train error 0.30,  test loss 1.319678, test error 37.20
# Epoch    35, train loss 0.087296, train error 0.30,  test loss 1.327042, test error 37.70
# Epoch    36, train loss 0.085292, train error 0.35,  test loss 1.337478, test error 37.00
# Epoch    37, train loss 0.083619, train error 0.30,  test loss 1.340651, test error 37.90
# Epoch    38, train loss 0.081180, train error 0.30,  test loss 1.343919, test error 37.50
# Epoch    39, train loss 0.079859, train error 0.22,  test loss 1.349032, test error 37.60
# Epoch    40, train loss 0.078113, train error 0.22,  test loss 1.353213, test error 37.50
# Epoch    41, train loss 0.077162, train error 0.22,  test loss 1.354045, test error 37.90
# Epoch    42, train loss 0.076552, train error 0.18,  test loss 1.358686, test error 37.80
# Epoch    43, train loss 0.075507, train error 0.20,  test loss 1.360092, test error 37.30
# Epoch    44, train loss 0.074656, train error 0.18,  test loss 1.362464, test error 37.70
# Epoch    45, train loss 0.073948, train error 0.20,  test loss 1.366758, test error 37.40
# Epoch    46, train loss 0.073016, train error 0.20,  test loss 1.369270, test error 38.00
# Epoch    47, train loss 0.072407, train error 0.18,  test loss 1.370515, test error 37.50
# Epoch    48, train loss 0.071501, train error 0.15,  test loss 1.375037, test error 37.40
# Epoch    49, train loss 0.070609, train error 0.18,  test loss 1.377548, test error 37.60

# %% [markdown]
# **TODO**: Plot the resulting quantities:
# - Train errors
# - Test errors
# - Train losses
# - Test losses

# %%
# Your code here
plot_results(errors_train, errors_test, losses_train, losses_test)

# %% [markdown]
# ### Part 1.b)
#
# Now let's increase the capacity of our model to have five hidden layers and re-run our experiment. Pay attention to what happens to the train and test curves.

# %% [markdown]
# **TODO:**
# Define a model with five hidden layers of size 100
# and ReLU activations between them

# %%
# Your code here:
model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o)
)

# %% [markdown]
# **TODO**: Train the model using the same code as above

# %%
# Your code here
errors_train, errors_test, losses_train, losses_test = train_model(model, data_loader, n_epoch=50)
# Out:
# Epoch     0, train loss 1.636196, train error 65.43,  test loss 1.690453, test error 67.00
# Epoch     1, train loss 1.486036, train error 60.47,  test loss 1.567001, test error 65.40
# Epoch     2, train loss 1.329862, train error 53.00,  test loss 1.460143, test error 58.00
# Epoch     3, train loss 1.113357, train error 45.47,  test loss 1.289397, test error 54.30
# Epoch     4, train loss 0.934279, train error 37.08,  test loss 1.189337, test error 46.90
# Epoch     5, train loss 0.926390, train error 38.47,  test loss 1.188367, test error 49.20
# Epoch     6, train loss 0.837562, train error 32.88,  test loss 1.190631, test error 46.80
# Epoch     7, train loss 0.727860, train error 28.97,  test loss 1.099211, test error 41.00
# Epoch     8, train loss 0.770109, train error 29.28,  test loss 1.255078, test error 47.10
# Epoch     9, train loss 0.618785, train error 23.07,  test loss 1.149563, test error 38.80
# Epoch    10, train loss 0.375007, train error 14.53,  test loss 1.117302, test error 35.60
# Epoch    11, train loss 0.297821, train error 10.18,  test loss 1.026514, test error 32.80
# Epoch    12, train loss 0.244214, train error 8.62,  test loss 1.218674, test error 34.00
# Epoch    13, train loss 0.218165, train error 7.38,  test loss 1.261716, test error 33.70
# Epoch    14, train loss 0.235162, train error 8.62,  test loss 1.380795, test error 35.60
# Epoch    15, train loss 0.175725, train error 5.88,  test loss 1.289708, test error 33.10
# Epoch    16, train loss 0.157763, train error 5.12,  test loss 1.423847, test error 34.70
# Epoch    17, train loss 0.154916, train error 5.65,  test loss 1.554500, test error 36.20
# Epoch    18, train loss 0.200317, train error 7.30,  test loss 1.458657, test error 34.50
# Epoch    19, train loss 0.152957, train error 5.32,  test loss 1.557720, test error 34.80
# Epoch    20, train loss 0.056491, train error 1.07,  test loss 1.396183, test error 31.90
# Epoch    21, train loss 0.026739, train error 0.25,  test loss 1.503590, test error 32.40
# Epoch    22, train loss 0.016778, train error 0.10,  test loss 1.560524, test error 31.60
# Epoch    23, train loss 0.011886, train error 0.05,  test loss 1.625704, test error 31.30
# Epoch    24, train loss 0.008562, train error 0.03,  test loss 1.685507, test error 31.70
# Epoch    25, train loss 0.006689, train error 0.03,  test loss 1.739825, test error 31.40
# Epoch    26, train loss 0.005632, train error 0.03,  test loss 1.773490, test error 31.80
# Epoch    27, train loss 0.004759, train error 0.03,  test loss 1.808676, test error 31.20
# Epoch    28, train loss 0.004145, train error 0.03,  test loss 1.848681, test error 31.50
# Epoch    29, train loss 0.003745, train error 0.03,  test loss 1.876544, test error 31.10
# Epoch    30, train loss 0.003384, train error 0.03,  test loss 1.888529, test error 31.50
# Epoch    31, train loss 0.003197, train error 0.00,  test loss 1.902667, test error 31.30
# Epoch    32, train loss 0.003015, train error 0.00,  test loss 1.916454, test error 31.30
# Epoch    33, train loss 0.002856, train error 0.00,  test loss 1.926088, test error 31.10
# Epoch    34, train loss 0.002718, train error 0.00,  test loss 1.938976, test error 31.30
# Epoch    35, train loss 0.002587, train error 0.00,  test loss 1.950262, test error 31.10
# Epoch    36, train loss 0.002472, train error 0.00,  test loss 1.960895, test error 31.10
# Epoch    37, train loss 0.002359, train error 0.00,  test loss 1.971668, test error 31.00
# Epoch    38, train loss 0.002261, train error 0.00,  test loss 1.982881, test error 31.10
# Epoch    39, train loss 0.002169, train error 0.00,  test loss 1.991983, test error 30.90
# Epoch    40, train loss 0.002125, train error 0.00,  test loss 1.997443, test error 31.00
# Epoch    41, train loss 0.002080, train error 0.00,  test loss 2.002146, test error 31.10
# Epoch    42, train loss 0.002039, train error 0.00,  test loss 2.007318, test error 31.10
# Epoch    43, train loss 0.002000, train error 0.00,  test loss 2.011666, test error 31.10
# Epoch    44, train loss 0.001963, train error 0.00,  test loss 2.016168, test error 31.10
# Epoch    45, train loss 0.001926, train error 0.00,  test loss 2.020935, test error 31.20
# Epoch    46, train loss 0.001891, train error 0.00,  test loss 2.025412, test error 31.20
# Epoch    47, train loss 0.001857, train error 0.00,  test loss 2.029613, test error 31.20
# Epoch    48, train loss 0.001824, train error 0.00,  test loss 2.034289, test error 31.20
# Epoch    49, train loss 0.001793, train error 0.00,  test loss 2.038759, test error 31.20

# %% [markdown]
# **TODO**: Plot the results using the same code as above

# %%
# Your code here
plot_results(errors_train, errors_test, losses_train, losses_test)

# %% [markdown]
# ### Part 1.c)
#
# Let's run one last experiment, this time with a simple linear model with **NO** hidden layers. In this case we will decrease the capacity of the model. Again, pay attention to what happens to the train and test curves.

# %% [markdown]
# **TODO:** Define a model with no hidden layers. This model should just be a linear layer that maps from the input dimension, `D_i` to the output dimension, `D_o`

# %%
# Your code here
model = nn.Sequential(
  nn.Linear(D_i, D_o)
)

# %% [markdown]
# **TODO**: Train the model using the same code as above

# %%
# Your code here
errors_train, errors_test, losses_train, losses_test = train_model(model, data_loader, n_epoch=50)
# Out:
# Epoch     0, train loss 1.770323, train error 70.50,  test loss 1.800859, test error 73.90
# Epoch     1, train loss 1.692427, train error 66.38,  test loss 1.733976, test error 70.80
# Epoch     2, train loss 1.662359, train error 66.80,  test loss 1.703289, test error 71.20
# Epoch     3, train loss 1.650183, train error 66.00,  test loss 1.683151, test error 69.30
# Epoch     4, train loss 1.643111, train error 66.03,  test loss 1.691110, test error 69.10
# Epoch     5, train loss 1.631000, train error 65.28,  test loss 1.680254, test error 69.10
# Epoch     6, train loss 1.625961, train error 64.12,  test loss 1.675030, test error 67.70
# Epoch     7, train loss 1.622756, train error 64.68,  test loss 1.682077, test error 68.80
# Epoch     8, train loss 1.622044, train error 64.68,  test loss 1.670664, test error 68.10
# Epoch     9, train loss 1.615664, train error 64.43,  test loss 1.669465, test error 68.60
# Epoch    10, train loss 1.601994, train error 63.08,  test loss 1.659341, test error 66.70
# Epoch    11, train loss 1.601764, train error 62.47,  test loss 1.666648, test error 68.30
# Epoch    12, train loss 1.599808, train error 63.12,  test loss 1.655825, test error 67.80
# Epoch    13, train loss 1.602114, train error 62.88,  test loss 1.660426, test error 67.70
# Epoch    14, train loss 1.598728, train error 62.40,  test loss 1.659771, test error 67.30
# Epoch    15, train loss 1.597522, train error 63.00,  test loss 1.660744, test error 68.10
# Epoch    16, train loss 1.598456, train error 62.67,  test loss 1.659370, test error 67.70
# Epoch    17, train loss 1.598934, train error 62.72,  test loss 1.661841, test error 68.00
# Epoch    18, train loss 1.598294, train error 63.25,  test loss 1.668577, test error 68.10
# Epoch    19, train loss 1.601398, train error 62.80,  test loss 1.665933, test error 68.40
# Epoch    20, train loss 1.593051, train error 62.78,  test loss 1.655582, test error 67.30
# Epoch    21, train loss 1.593652, train error 62.55,  test loss 1.657832, test error 66.60
# Epoch    22, train loss 1.593952, train error 62.22,  test loss 1.653423, test error 67.50
# Epoch    23, train loss 1.593305, train error 62.38,  test loss 1.661161, test error 68.00
# Epoch    24, train loss 1.593243, train error 62.38,  test loss 1.658240, test error 67.00
# Epoch    25, train loss 1.592977, train error 62.60,  test loss 1.656149, test error 66.60
# Epoch    26, train loss 1.592509, train error 62.67,  test loss 1.659756, test error 67.80
# Epoch    27, train loss 1.594019, train error 62.58,  test loss 1.657522, test error 66.80
# Epoch    28, train loss 1.591403, train error 62.85,  test loss 1.657502, test error 67.30
# Epoch    29, train loss 1.591395, train error 62.38,  test loss 1.656687, test error 66.80
# Epoch    30, train loss 1.590854, train error 62.40,  test loss 1.655262, test error 67.50
# Epoch    31, train loss 1.590747, train error 62.28,  test loss 1.655101, test error 67.60
# Epoch    32, train loss 1.590931, train error 62.25,  test loss 1.656924, test error 67.00
# Epoch    33, train loss 1.590553, train error 62.42,  test loss 1.655782, test error 67.00
# Epoch    34, train loss 1.590540, train error 62.58,  test loss 1.657519, test error 67.60
# Epoch    35, train loss 1.590546, train error 62.08,  test loss 1.656046, test error 67.20
# Epoch    36, train loss 1.590269, train error 62.53,  test loss 1.655664, test error 67.00
# Epoch    37, train loss 1.590261, train error 62.65,  test loss 1.657163, test error 67.10
# Epoch    38, train loss 1.590227, train error 62.50,  test loss 1.655931, test error 67.20
# Epoch    39, train loss 1.590213, train error 62.20,  test loss 1.656365, test error 67.00
# Epoch    40, train loss 1.589994, train error 62.22,  test loss 1.655985, test error 67.20
# Epoch    41, train loss 1.589953, train error 62.20,  test loss 1.656157, test error 67.00
# Epoch    42, train loss 1.589919, train error 62.15,  test loss 1.654741, test error 67.30
# Epoch    43, train loss 1.589897, train error 62.55,  test loss 1.657024, test error 66.70
# Epoch    44, train loss 1.589799, train error 62.62,  test loss 1.655909, test error 67.40
# Epoch    45, train loss 1.589773, train error 62.40,  test loss 1.656157, test error 66.90
# Epoch    46, train loss 1.589724, train error 62.12,  test loss 1.655771, test error 67.50
# Epoch    47, train loss 1.589736, train error 62.58,  test loss 1.656293, test error 66.80
# Epoch    48, train loss 1.589686, train error 62.45,  test loss 1.656492, test error 67.20
# Epoch    49, train loss 1.589662, train error 62.35,  test loss 1.656345, test error 67.30

# %% [markdown]
# **TODO**: Plot the results using the same code as above

# %%
# Your code here
plot_results(errors_train, errors_test, losses_train, losses_test)

# %%
# input layer and output layer with relu between.
model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o),
)

# %%
errors_train, errors_test, losses_train, losses_test = train_model(model, data_loader, n_epoch=50)
# Out:
# Epoch     0, train loss 1.649285, train error 64.47,  test loss 1.727760, test error 69.30
# Epoch     1, train loss 1.474754, train error 58.08,  test loss 1.586269, test error 64.90
# Epoch     2, train loss 1.289241, train error 47.50,  test loss 1.417217, test error 55.70
# Epoch     3, train loss 1.177214, train error 41.78,  test loss 1.332710, test error 51.50
# Epoch     4, train loss 1.075714, train error 37.67,  test loss 1.252906, test error 49.10
# Epoch     5, train loss 1.029163, train error 37.15,  test loss 1.224586, test error 47.10
# Epoch     6, train loss 0.961498, train error 34.45,  test loss 1.191142, test error 47.70
# Epoch     7, train loss 0.938476, train error 33.82,  test loss 1.177241, test error 46.70
# Epoch     8, train loss 0.866968, train error 30.30,  test loss 1.129548, test error 44.40
# Epoch     9, train loss 0.846989, train error 29.93,  test loss 1.133920, test error 43.10
# Epoch    10, train loss 0.802605, train error 28.15,  test loss 1.102605, test error 43.60
# Epoch    11, train loss 0.793576, train error 28.12,  test loss 1.100697, test error 42.60
# Epoch    12, train loss 0.767180, train error 26.22,  test loss 1.089137, test error 43.10
# Epoch    13, train loss 0.754499, train error 25.75,  test loss 1.088106, test error 43.60
# Epoch    14, train loss 0.742462, train error 25.03,  test loss 1.086008, test error 42.00
# Epoch    15, train loss 0.739393, train error 26.15,  test loss 1.097256, test error 42.80
# Epoch    16, train loss 0.721154, train error 25.15,  test loss 1.102320, test error 43.30
# Epoch    17, train loss 0.706437, train error 23.95,  test loss 1.088377, test error 42.50
# Epoch    18, train loss 0.698814, train error 24.05,  test loss 1.099838, test error 42.20
# Epoch    19, train loss 0.688234, train error 23.95,  test loss 1.108388, test error 42.40
# Epoch    20, train loss 0.674214, train error 23.00,  test loss 1.094198, test error 41.80
# Epoch    21, train loss 0.664587, train error 22.38,  test loss 1.083280, test error 42.00
# Epoch    22, train loss 0.663658, train error 22.18,  test loss 1.089485, test error 41.50
# Epoch    23, train loss 0.656717, train error 22.28,  test loss 1.084157, test error 41.20
# Epoch    24, train loss 0.655669, train error 22.28,  test loss 1.094427, test error 41.80
# Epoch    25, train loss 0.648068, train error 22.05,  test loss 1.090229, test error 42.00
# Epoch    26, train loss 0.643187, train error 21.90,  test loss 1.096615, test error 41.70
# Epoch    27, train loss 0.638529, train error 21.55,  test loss 1.097744, test error 42.00
# Epoch    28, train loss 0.631303, train error 21.20,  test loss 1.094949, test error 40.90
# Epoch    29, train loss 0.634168, train error 21.43,  test loss 1.103375, test error 41.80
# Epoch    30, train loss 0.625293, train error 20.82,  test loss 1.099740, test error 41.70
# Epoch    31, train loss 0.621559, train error 20.62,  test loss 1.097633, test error 41.50
# Epoch    32, train loss 0.618331, train error 20.53,  test loss 1.097898, test error 41.40
# Epoch    33, train loss 0.616680, train error 20.25,  test loss 1.102330, test error 42.30
# Epoch    34, train loss 0.614951, train error 20.78,  test loss 1.103612, test error 41.00
# Epoch    35, train loss 0.612028, train error 20.12,  test loss 1.102176, test error 41.50
# Epoch    36, train loss 0.610136, train error 20.50,  test loss 1.101488, test error 42.00
# Epoch    37, train loss 0.608866, train error 20.65,  test loss 1.107700, test error 42.10
# Epoch    38, train loss 0.607140, train error 20.40,  test loss 1.105331, test error 41.70
# Epoch    39, train loss 0.603671, train error 20.03,  test loss 1.108948, test error 42.00
# Epoch    40, train loss 0.601659, train error 19.90,  test loss 1.104992, test error 40.90
# Epoch    41, train loss 0.600497, train error 19.90,  test loss 1.105229, test error 41.50
# Epoch    42, train loss 0.599337, train error 19.82,  test loss 1.104778, test error 41.40
# Epoch    43, train loss 0.599759, train error 19.72,  test loss 1.106151, test error 41.30
# Epoch    44, train loss 0.597252, train error 19.65,  test loss 1.107643, test error 42.10
# Epoch    45, train loss 0.596962, train error 19.65,  test loss 1.106910, test error 40.90
# Epoch    46, train loss 0.595115, train error 19.65,  test loss 1.108099, test error 41.30
# Epoch    47, train loss 0.594784, train error 19.55,  test loss 1.109263, test error 41.80
# Epoch    48, train loss 0.593395, train error 19.62,  test loss 1.108417, test error 41.70
# Epoch    49, train loss 0.592587, train error 19.60,  test loss 1.109730, test error 41.30

# %%
plot_results(errors_train, errors_test, losses_train, losses_test)

# %%
# 2 hidden layers
model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o),
)

# %%
errors_train, errors_test, losses_train, losses_test = train_model(model, data_loader, n_epoch=50)
# Out:
# Epoch     0, train loss 1.583468, train error 62.20,  test loss 1.667775, test error 67.00
# Epoch     1, train loss 1.287562, train error 47.95,  test loss 1.436650, test error 57.10
# Epoch     2, train loss 1.120228, train error 41.55,  test loss 1.339805, test error 52.20
# Epoch     3, train loss 1.061046, train error 42.83,  test loss 1.382789, test error 52.80
# Epoch     4, train loss 0.826810, train error 29.53,  test loss 1.172334, test error 45.70
# Epoch     5, train loss 0.709501, train error 26.38,  test loss 1.142510, test error 44.60
# Epoch     6, train loss 0.667895, train error 24.97,  test loss 1.164219, test error 43.80
# Epoch     7, train loss 0.539326, train error 19.82,  test loss 1.164362, test error 41.00
# Epoch     8, train loss 0.490163, train error 17.90,  test loss 1.168392, test error 40.30
# Epoch     9, train loss 0.453024, train error 16.55,  test loss 1.203571, test error 41.20
# Epoch    10, train loss 0.264287, train error 7.00,  test loss 1.074820, test error 37.60
# Epoch    11, train loss 0.225898, train error 6.35,  test loss 1.103319, test error 36.60
# Epoch    12, train loss 0.176347, train error 4.12,  test loss 1.152909, test error 36.50
# Epoch    13, train loss 0.147641, train error 2.93,  test loss 1.165635, test error 37.10
# Epoch    14, train loss 0.134446, train error 2.80,  test loss 1.268196, test error 38.20
# Epoch    15, train loss 0.103270, train error 1.45,  test loss 1.237892, test error 36.80
# Epoch    16, train loss 0.080657, train error 0.82,  test loss 1.289642, test error 36.70
# Epoch    17, train loss 0.072220, train error 0.75,  test loss 1.377249, test error 36.90
# Epoch    18, train loss 0.053012, train error 0.25,  test loss 1.364377, test error 36.10
# Epoch    19, train loss 0.043739, train error 0.10,  test loss 1.391173, test error 35.50
# Epoch    20, train loss 0.032918, train error 0.05,  test loss 1.409422, test error 36.50
# Epoch    21, train loss 0.029474, train error 0.00,  test loss 1.426989, test error 35.60
# Epoch    22, train loss 0.026597, train error 0.00,  test loss 1.458510, test error 36.40
# Epoch    23, train loss 0.024514, train error 0.00,  test loss 1.478968, test error 36.50
# Epoch    24, train loss 0.022917, train error 0.00,  test loss 1.498695, test error 36.30
# Epoch    25, train loss 0.021480, train error 0.00,  test loss 1.508587, test error 35.50
# Epoch    26, train loss 0.020038, train error 0.00,  test loss 1.526201, test error 36.50
# Epoch    27, train loss 0.018819, train error 0.00,  test loss 1.549134, test error 36.00
# Epoch    28, train loss 0.017806, train error 0.00,  test loss 1.560586, test error 35.90
# Epoch    29, train loss 0.017247, train error 0.00,  test loss 1.577484, test error 35.80
# Epoch    30, train loss 0.016277, train error 0.00,  test loss 1.579687, test error 36.10
# Epoch    31, train loss 0.015830, train error 0.00,  test loss 1.587091, test error 35.80
# Epoch    32, train loss 0.015404, train error 0.00,  test loss 1.595420, test error 36.30
# Epoch    33, train loss 0.015026, train error 0.00,  test loss 1.602776, test error 35.80
# Epoch    34, train loss 0.014661, train error 0.00,  test loss 1.606562, test error 36.10
# Epoch    35, train loss 0.014373, train error 0.00,  test loss 1.619115, test error 36.20
# Epoch    36, train loss 0.014004, train error 0.00,  test loss 1.620907, test error 35.80
# Epoch    37, train loss 0.013716, train error 0.00,  test loss 1.631561, test error 36.10
# Epoch    38, train loss 0.013477, train error 0.00,  test loss 1.633878, test error 36.00
# Epoch    39, train loss 0.013140, train error 0.00,  test loss 1.640842, test error 36.00
# Epoch    40, train loss 0.012934, train error 0.00,  test loss 1.644139, test error 35.80
# Epoch    41, train loss 0.012795, train error 0.00,  test loss 1.647416, test error 35.80
# Epoch    42, train loss 0.012659, train error 0.00,  test loss 1.649157, test error 35.80
# Epoch    43, train loss 0.012528, train error 0.00,  test loss 1.654031, test error 35.90
# Epoch    44, train loss 0.012399, train error 0.00,  test loss 1.655899, test error 35.80
# Epoch    45, train loss 0.012305, train error 0.00,  test loss 1.658719, test error 35.70
# Epoch    46, train loss 0.012149, train error 0.00,  test loss 1.662329, test error 35.80
# Epoch    47, train loss 0.012025, train error 0.00,  test loss 1.664511, test error 35.80
# Epoch    48, train loss 0.011907, train error 0.00,  test loss 1.666338, test error 35.80
# Epoch    49, train loss 0.011795, train error 0.00,  test loss 1.670941, test error 35.90

# %%
plot_results(errors_train, errors_test, losses_train, losses_test)

# %% [markdown]
# ### Part 1.d: Discussion
# What did you observe as you changed the model capacity in your experiments? What are some measures you might include to improve generalization of your models?

# %%
# Your response here

# %% [markdown]
# **Observations:**
#
# I noticed as I increased the capacity of the model it would overfit to the training set thus performing very well on the training set and horrible on the test set. It seemed to me with my brief experimentation that the optimal model, without any additional measurements or validation set included, was a simple model with 1 input layer and 1 output layer with a relu in between. The moment I went past that the peformance with the test set went bad.
#
# **Measurments to help the overfit and improve generalization**
#
# I would look into how I can find the right balance between the variance and the bias. We don't want to decrease the variance so much that we increase our bias too much and we also don't want to decrease our bias so much that we increase our variance too much. I would do some testing looking at both these measurements and to try find the sweet spot that balances both of them which will increase our models chances at generalizing better to unseen data.

# %% [markdown]
# ## Q2:  Bias-variance Trade-off
#
# In this problem, we will investigate the bias-variance trade-off and reproduce the curves seen in Figure 8.8 in Prince.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Let's specify the true function that we are trying to estimate, defined on [0,1]

# %%
def true_function(x):
    y = np.exp(np.sin(x*(2*3.1413)))
    return y

# %% [markdown]
# Now let's generate some data point and add bit of noise to the labels

# %%
def generate_data(n_data, sigma_y=0.3):
    # Generate x values quasi uniformly
    x = np.ones(n_data)
    for i in range(n_data):
        x[i] = np.random.uniform(i/n_data, (i+1)/n_data, 1)

    # y value from running through function and adding noise
    y = np.ones(n_data)
    for i in range(n_data):
        y[i] = true_function(x[i])
        y[i] += np.random.normal(0, sigma_y, 1)
    return x,y

# %% [markdown]
# Let's draw the fitted function, together with uncertainty used to generate points

# %%
def plot_function(x_func, y_func, x_data=None,y_data=None, x_model = None, y_model =None, sigma_func = None, sigma_model=None):

    fig,ax = plt.subplots()
    ax.plot(x_func, y_func, 'k-')
    if sigma_func is not None:
      ax.fill_between(x_func, y_func-2*sigma_func, y_func+2*sigma_func, color='lightgray')

    if x_data is not None:
        ax.plot(x_data, y_data, 'o', color='#d18362')

    if x_model is not None:
        ax.plot(x_model, y_model, '-', color='#7fe7de')

    if sigma_model is not None:
      ax.fill_between(x_model, y_model-2*sigma_model, y_model+2*sigma_model, color='lightgray')

    ax.set_xlim(0,1)
    ax.set_xlabel('Input, x')
    ax.set_ylabel('Output, y')
    plt.show()
    plt.show()

# %% [markdown]
# Sample from the true function (no noise):

# %%
x_func = np.linspace(0, 1.0, 100)
y_func = true_function(x_func);

# %% [markdown]
# Generate some training data (with noise):

# %%
np.random.seed(1)
sigma_func = 0.3
n_data = 15
x_data,y_data = generate_data(n_data, sigma_func)
# Out:
# <ipython-input-28-9b4b2e18b177>:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x[i] = np.random.uniform(i/n_data, (i+1)/n_data, 1)
# <ipython-input-28-9b4b2e18b177>:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i] += np.random.normal(0, sigma_y, 1)

# %% [markdown]
# Plot the data with the functions defined above

# %%
plot_function(x_func, y_func, x_data, y_data, sigma_func=sigma_func)

# %%
# Define model -- beta is a scalar and omega has size n_hidden,1
def network(x, beta, omega):
    # Retrieve number of hidden units
    n_hidden = omega.shape[0]

    y = np.zeros_like(x)
    for c_hidden in range(n_hidden):
        # Evaluate activations based on shifted lines (figure 8.4b-d)
        line_vals =  x  - c_hidden/n_hidden
        h =  line_vals * (line_vals > 0)
        # Weight activations by omega parameters and sum
        y = y + omega[c_hidden] * h
    # Add bias, beta
    y = y + beta

    return y

# %%
# This fits the n_hidden+1 parameters (see fig 8.4a) in closed form.
# If you have studied linear algebra, then you will know it is a least
# squares solution of the form (A^TA)^-1A^Tb.  If you don't recognize that,
# then just take it on trust that this gives you the best possible solution.
def fit_model_closed_form(x,y,n_hidden):
  n_data = len(x)
  A = np.ones((n_data, n_hidden+1))
  for i in range(n_data):
      for j in range(1,n_hidden+1):
          A[i,j] = x[i]-(j-1)/n_hidden
          if A[i,j] < 0:
              A[i,j] = 0;

  beta_omega = np.linalg.lstsq(A, y, rcond=None)[0]

  beta = beta_omega[0]
  omega = beta_omega[1:]

  return beta, omega

# %%
# Closed form solution
beta, omega = fit_model_closed_form(x_data,y_data,n_hidden=3)

# Get prediction for model across graph range
x_model = np.linspace(0,1,100);
y_model = network(x_model, beta, omega)

# Draw the function and the model
plot_function(x_func, y_func, x_data,y_data, x_model, y_model)

# %% [markdown]
# ### Part 2.a) Estimating the mean and variance of the model outputs, over many training runs

# %% [markdown]
# **TODO:** Fill in the missing pieces of this function to tun the model many times with different datasets and return the mean and variance

# %%
def get_model_mean_variance(n_data, n_datasets, n_hidden, sigma_func):

  # Create array that stores model results in rows
  y_model_all = np.zeros((n_datasets, n_data))

  for c_dataset in range(n_datasets):
    # TODO -- Generate n_data x,y, pairs with standard deviation sigma_func
    # Replace this line
    x_data, y_data = generate_data(n_data, sigma_func)

    # TODO -- Fit the model
    # Replace this line:
    beta, omega = fit_model_closed_form(x_data, y_data, n_hidden=n_hidden)

    # TODO -- Run the fitted model on x_model
    # Replace this line
    y_model = network(x_data, beta, omega)

    # Store the model results
    y_model_all[c_dataset,:] = y_model

  # Get mean and standard deviation of model
  mean_model = np.mean(y_model_all,axis=0)
  std_model = np.std(y_model_all,axis=0)

  # Return the mean and standard deviation of the fitted model
  return mean_model, std_model

# %% [markdown]
# Let's generate N=100 random data sets, fit the model N=100 times and look the mean and variance. Here we will have 15 data points and 3 hidden units in our model:

# %%
n_datasets = 100
n_data = 15
sigma_func = 0.3
n_hidden = 3

# Get mean and variance of fitted model
np.random.seed(1)
mean_model, std_model = get_model_mean_variance(n_data, n_datasets, n_hidden, sigma_func)
# Out:
# <ipython-input-28-9b4b2e18b177>:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x[i] = np.random.uniform(i/n_data, (i+1)/n_data, 1)
# <ipython-input-28-9b4b2e18b177>:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i] += np.random.normal(0, sigma_y, 1)

# %% [markdown]
# Plot the results

# %%
x_model_grid = np.linspace(0, 1, len(mean_model))
plot_function(x_func, y_func, x_model=x_model_grid, y_model=mean_model, sigma_model=std_model)

# %% [markdown]
# If you did this correctly, you can see that there that we observe both **bias** and **variance** in the model outputs. Here bias refers to the fact that we have some error from the model outputs and the true function (distance between cyan and black lines); variance refers to the gray region indicating there is a fair amount of variability in what the model outputs over each dataset it sees.

# %% [markdown]
# ### Part 2.b) Changing the amount of available data

# %% [markdown]
# **TODO**: Let's rerun the same experiment as the cell above, but this time let's increase the the number of training points to 100, `n_data=100`

# %%
n_datasets = 100
n_data = 100
sigma_func = 0.3
n_hidden = 3

# Get mean and variance of fitted model
np.random.seed(1)
mean_model, std_model = get_model_mean_variance(n_data, n_datasets, n_hidden, sigma_func)
# Out:
# <ipython-input-28-9b4b2e18b177>:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x[i] = np.random.uniform(i/n_data, (i+1)/n_data, 1)
# <ipython-input-28-9b4b2e18b177>:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i] += np.random.normal(0, sigma_y, 1)

# %% [markdown]
# **TODO**: Plot the results:

# %%
x_model_grid = np.linspace(0, 1, len(mean_model))
plot_function(x_func, y_func, x_model=x_model_grid, y_model=mean_model, sigma_model=std_model)

# %% [markdown]
# **TODO**: What happened to the variance? Record your observations

# %% [markdown]
# The variance shrunk and the bias looks like it increased since the blue line has less joints with the distance between the blue line and black line increased at several regions. This demonstrates the bias variance trade off where we decreased the variance by increasing our training points, but this increases our bias which is the error between the model output (cyan line) and real output (black line). Something I also noticed is you can see this tradeoff in certain points in the plot where if the blue line matches up with the black line meaning very low bias the width in the variance gray region is often higher.

# %% [markdown]
# ### Part 2.c) Increasing the model capacity

# %% [markdown]
# **TODO**: Let's rerun the same experiment as the cell above, but this time let's increase set the number of hidden units to 12 and the number of training points to 15

# %%
n_datasets = 100
n_data = 15
sigma_func = 0.3
n_hidden = 12

# Get mean and variance of fitted model
np.random.seed(1)
mean_model, std_model = get_model_mean_variance(n_data, n_datasets, n_hidden, sigma_func)
# Out:
# <ipython-input-28-9b4b2e18b177>:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x[i] = np.random.uniform(i/n_data, (i+1)/n_data, 1)
# <ipython-input-28-9b4b2e18b177>:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i] += np.random.normal(0, sigma_y, 1)

# %% [markdown]
# **TODO**: Plot the results

# %%
x_model_grid = np.linspace(0, 1, len(mean_model))
plot_function(x_func, y_func, x_model=x_model_grid, y_model=mean_model, sigma_model=std_model)

# %% [markdown]
# **TODO**: What happened to the bias? Record your observations

# %% [markdown]
# In this case the bias decreased meaning the error between the real output(black line) and the model(cyan) output decreased. We can see this based on how the blue line has a lot more joints that go with the black line making it so the blue line matches up a lot better with the black line. But this also demonstrates the trade off between variance and bias again because since we decreased the bias we then increased the variance making the gray regions wider around the black line. I also noticed in this plot that points where the cyan line and black line exactly match up the width of the variance region would increase

# %% [markdown]
# ### Part 2.d) High capacity and high data

# %% [markdown]
# **TODO**: Let's rerun the same experiment as the cell above, but this time let's increase set the number of hidden units to 12 and the number of training points to 1000

# %%
n_datasets = 100
n_data = 1000
sigma_func = 0.3
n_hidden = 12

# Get mean and variance of fitted model
np.random.seed(1)
mean_model, std_model = get_model_mean_variance(n_data, n_datasets, n_hidden, sigma_func)
# Out:
# <ipython-input-28-9b4b2e18b177>:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x[i] = np.random.uniform(i/n_data, (i+1)/n_data, 1)
# <ipython-input-28-9b4b2e18b177>:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y[i] += np.random.normal(0, sigma_y, 1)

# %% [markdown]
# **TODO:** Plot the results

# %%
x_model_grid = np.linspace(0, 1, len(mean_model))
plot_function(x_func, y_func, x_model=x_model_grid, y_model=mean_model, sigma_model=std_model)

# %% [markdown]
# **TODO**: Record your observations about the bias and variance in this setting

# %% [markdown]
# In this case we had a lot more training points (1000) and a good same amount of hidden units (12). The bias in this plot is very small with the blue line matching up very well with the black line meaning there is minimal error between the real output the model output. Although there is still a significant deviation at x=0.3 where we can see the blue line peaks and doesn't match well with the black line. The variance is also very low as you can see with the gray region along the black line having a very small width. The variance is also a lot lower at the outer edges of the input at x = 0 and x = 1. This shows the model is generalizing with those more "extreme" values of our input.
#
# Overall with this plot we can see that the bias is reduced significantly, and the variance remains controlled, which indicates that the model is maintaing a good balance between variance and bias.

# %% [markdown]
# ## Q3) High Dimensional Spaces
# This question investigates the strange properties of high-dimensional spaces as discussed in the notes at the end of chapter 8.

# %%
from scipy.spatial.distance import pdist

# %%
# Fix the random seed so we all have the same random numbers
np.random.seed(0)
n_data = 1000
# Create 1000 data examples (columns) each with 2 dimensions (rows)
n_dim = 2
x_2D = np.random.normal(size=(n_dim,n_data))
# Create 1000 data examples (columns) each with 100 dimensions (rows)
n_dim = 100
x_100D = np.random.normal(size=(n_dim,n_data))
# Create 1000 data examples (columns) each with 1000 dimensions (rows)
n_dim = 1000
x_1000D = np.random.normal(size=(n_dim,n_data))

# %% [markdown]
# **TODO:** Implement the missing parts of the function below:

# %%
def distance_ratio(x):
  # TODO -- replace the two lines below to calculate the largest and smallest Euclidean distance between
  # the data points in the columns of x.  DO NOT include the distance between the data point
  # and itself (which is obviously zero)

  distances = pdist(x.T, 'euclidean')

  smallest_dist = np.min(distances)
  largest_dist = np.max(distances)

  # Calculate the ratio and return
  dist_ratio = largest_dist / smallest_dist
  return dist_ratio

# %%
print('Ratio of largest to smallest distance 2D: %3.3f'%(distance_ratio(x_2D)))
print('Ratio of largest to smallest distance 100D: %3.3f'%(distance_ratio(x_100D)))
print('Ratio of largest to smallest distance 1000D: %3.3f'%(distance_ratio(x_1000D)))
# Out:
# Ratio of largest to smallest distance 2D: 2840.258
# Ratio of largest to smallest distance 100D: 2.038
# Ratio of largest to smallest distance 1000D: 1.221

# %% [markdown]
# If you did this right, you will see that the distance between the nearest and farthest two points in high dimensions is almost the same.
