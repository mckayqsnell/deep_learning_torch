# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/porterjenkins/byu-cs474/blob/master/lab3_cross_entropy_convnets.ipynb)

# %% [markdown]
# # Deep Learning Part 3: Datasets, Data Loading, Cross Entropy, and Convolutional Networks
#
# ## Grading Standards:
# *  10%: Dataset/MNIST section
# *  10%: Correct implementation and use of cross entropy loss
# *  20%: Correct training/validation functions
# *  40%: Successful training and validation with MLP and convolution networks
# *  12%: Convolutional layer quiz
# *   8%: Comparison between MLP and convolution networks
# ___

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# Set your global variable `device`, using the `torch.device()` function. In order to use cuda remember to request a GPU from Runtime > Change Runtime.
#
# ***Important Note**: If you spend too much time or memory on the GPU in Google Colab then you will be timed out. This may not be a big deal with this lab, but it can become a big deal in later labs. It is recommended to set your `device` and Runtime to CPU first and once everything in the lab is working properly to set it to the GPU.*

# %%
device = torch.device('cuda')

# %%
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# We are going to make a PyTorch `Dataset`.
# There are three parts to creating a `Dataset`:
# 1. `__init__()`: This is where you get all relevant data for your dataset.
# 2. `__len__()`: You return how large your dataset is.
# 3. `__getitem__()`: You return an item from your dataset given an index.
#
# Implement the TODOs below.

# %%
class SineDataset(Dataset):
    def __init__(self):
        # TODO: The code is same from lab 2, so you can uncomment the code below.
        self.x = torch.rand((100,1))*8 - 4
        self.y = torch.sin(self.x) + torch.randn_like(self.x)*.1 # the second part of the sum adds noise to the function

    def __len__(self):
        # TODO: Return the len of your dataset.
        return len(self.x)

    def __getitem__(self, i):
        # TODO: i will be an index so return x_i and y_i
        return self.x[i], self.y[i]

# %% [markdown]
# Now create a `SineDataset` and print out the length of dataset, i.e. `len(dataset)`, and the item in your dataset at index 0, i.e. `dataset[0]`.

# %%
dataset = SineDataset()
print(len(dataset))
# Out:
# 100

# %% [markdown]
# A `DataLoader` uses the `__len__` and `__getitem__` of a `Dataset` to sample indices in `[0, ..., len(dataset)-1]` and collect a batch of items from the `Dataset`.
# The `DataLoader` will then try to convert the sampled entries into tensors (if they are not already) and concatenate them together.
# Create a `DataLoader` object below; pass in your dataset and `batch_size=32` as arguments.

# %%
dataloader = DataLoader(dataset, batch_size=32)

# %% [markdown]
# Iterate through your dataloader with a for loop. Because `SineDataset.__getitem__()` returns two items, the for loop will return a tuple.
# Either unpack the entries in your tuple in the for loop:
# ```python
# for x, y in dataloader
# ```
# or after the loop:
# ```python
# for batch in dataloader:
#     x, y = batch
# ```
#
# Print out the shapes of `x` and `y` for each batch in the dataloader.

# %%
for x, y in dataloader:
  print("x:" , x.shape, " y:", y.shape)
# Out:
# x: torch.Size([32, 1])  y: torch.Size([32, 1])
# x: torch.Size([32, 1])  y: torch.Size([32, 1])
# x: torch.Size([32, 1])  y: torch.Size([32, 1])
# x: torch.Size([4, 1])  y: torch.Size([4, 1])

# %% [markdown]
# You will notice that the shapes are `(B, Z_in)`, where `B` is batch size and `Z_in` is our input feature size, which is exactly what we want.
# Also note that the last batch has a batch size of 4; this is because the `DataLoader` samples **without replacement** and these are the last items in our `Dataset` that have not been sampled.
#
# Let's now create our real dataset.

# %% [markdown]
# ---
#
# # MNIST
#
# We are now going to look at the MNIST dataset, which is a dataset of handwritten numbers.
# Our objective will be to create a neural network that can predict the number given the image.
#
# First import `torchvision` below so we can retrieve the MNIST dataset.

# %%
import torchvision

# %% [markdown]
# You can use `torchvision.datasets.MNIST()` to download the MNIST dataset (which inherits the `Dataset` class).
# For arguments, specify `root="/tmp/"` to denote the location, `train=True` or `train=False` to get the training or test dataset, `download=True` to specify you want to download the dataset, and `transform=torchvision.transforms.ToTensor()` to convert the MNIST images from PIL images to PyTorch tensors.
# Create both a `train_dataset` and `val_dataset`.
#
# *Note: It is good practice to use a train, val, and test dataset, especially in the real world, but in this class we will mainly focus on train and val datasets to simplify things.*

# %%
train_dataset = torchvision.datasets.MNIST(root="/tmp/", train=True, download=True, transform=torchvision.transforms.ToTensor())
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to /tmp/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 14479898.01it/s]
# Extracting /tmp/MNIST/raw/train-images-idx3-ubyte.gz to /tmp/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to /tmp/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 444774.59it/s]
# Extracting /tmp/MNIST/raw/train-labels-idx1-ubyte.gz to /tmp/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to /tmp/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 3950454.83it/s]
# Extracting /tmp/MNIST/raw/t10k-images-idx3-ubyte.gz to /tmp/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to /tmp/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 5874353.61it/s]
# Extracting /tmp/MNIST/raw/t10k-labels-idx1-ubyte.gz to /tmp/MNIST/raw

# %%
val_dataset = torchvision.datasets.MNIST(root="/tmp/", train=False, download=True, transform=torchvision.transforms.ToTensor())

# %% [markdown]
# Print out the lengths of `train_dataset` and `val_dataset`.

# %%
len(train_dataset)
# Out:
# 60000

# %%
len(val_dataset)
# Out:
# 10000

# %% [markdown]
# Grab element 0 from the `train_dataset`. As a heads up, like our `SineDataset`, `MNIST` returns an image `x` and a class/target `y`.

# %%
x, y = train_dataset.__getitem__(0)

# %% [markdown]
# Use the `type()` function to see what type of object `x` and `y` are.

# %%
type(x)
# Out:
# torch.Tensor

# %%
type(y)
# Out:
# int

# %% [markdown]
# Since x is a tensor, print out its `.dtype`, `.shape`

# %%
print(x.dtype, x.shape)
# Out:
# torch.float32 torch.Size([1, 28, 28])

# %% [markdown]
# The shape of a tensor image is `(C, H, W)`, where `C` is channels, `H` is height, and `W` is width.
# In our case `x` has 1 channel and it is a 28x28 image.
# Because there is 1 channel, it is likely that the image is grayscale (which it is).
#
# Now visualize the image and display its class.
# Use the `plt.imshow()` function to visualize `x`; add the argument `cmap="gray"` to denote the image is grayscale.
# Use the `plt.title()` function to set the title of the `plt` image to the class `y`.
#
# *Note: `plt` expects grayscale images to only have to dimension, HxW, so `.squeeze()` the 0th dimension*

# %%
plt.imshow(x.squeeze(0), cmap="gray")
plt.title(y)
# Out:
# Text(0.5, 1.0, '5')

# %% [markdown]
# Print out the min and max values of `x` using `torch.min()` and `torch.max()`.

# %%
print("min:", torch.min(x), "max:", torch.max(x))
# Out:
# min: tensor(0.) max: tensor(1.)

# %% [markdown]
# Our tensors are normalized between 0 and 1, which is good so we don't have to do any normalization.
# Now that we have a better understanding of our image data, let's examine the classes in the dataset.
#
# Create a `get_dataset_classes()` function which takes a dataset as input and count how many times each class appears.
# Return a dictionary where the keys are the classes and the values represent the number of times each class appears in the dataset.

# %%
def get_dataset_classes(dataset):
  class_counts = {}

  for _, label in dataset:
      if label in class_counts:
          class_counts[label] += 1
      else:
          class_counts[label] = 1

  return class_counts

# %% [markdown]
# Execute the code below to visualize the dataset classes.

# %%
train_classes = get_dataset_classes(train_dataset)
val_classes = get_dataset_classes(val_dataset)

def plot_classes(ax, classes, title):
    ax.bar(classes.keys(), classes.values())
    ax.set_title(title)
    ax.set_xticks(list(range(10)))

fig, axes = plt.subplots(1, 2, figsize=(8, 4))
plot_classes(axes[0], train_classes, "Train Dataset Classes")
plot_classes(axes[1], val_classes, "Val Dataset Classes")
plt.show()

# %% [markdown]
# There are 10 classes, which makes sense because there are 10 digits, 0-9.
# Furthermore, the classes are pretty evenly spread on both datasets, which means our baseline accuracy is roughly 10%.
#
# Now create two `DataLoader` objects called, `train_loader` and `val_loader`.
# The `train_loader` should have your `train_dataset` and the `val_loader` should have your `val_dataset`.
# Set the `batch_size` of both dataloaders equal to 32 and set `shuffle=True` for the `train_loader` so that the dataset is shuffled every time.
# To improve the speed at which you `DataLoader`s can load the data, set `num_workers=4` (for multiprocessing).

# %%
train_loader = DataLoader(train_dataset, 32, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, 32, num_workers=4)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# Now use `x, y = next(iter(train_loader))` to get a single batch of data from the `train_loader` and print out the shapes and dtypes of `x` and `y`

# %%
x, y = next(iter(train_loader))
print("x:", x.shape, x.dtype)
print("y:", y.shape, y.dtype)
# Out:
# x: torch.Size([32, 1, 28, 28]) torch.float32
# y: torch.Size([32]) torch.int64

# %% [markdown]
# The shape of `x` is `(B, C, H, W)`, where `B` is the batch size. **Always remember, in PyTorch, your data should have a batch dimension.**
# The shape of `y` is `(B,)` and it is a tensor of type `long`, which is what we want because we are doing classification, which means we want our target to be a class label.

# %% [markdown]
# ___
#
# ### MLP Network
#
# We are now going to make our network.
# Because we are doing image classification, the input to our network is a batch of images, `shape=(B, C, H, W)`, and the output of our network is a batch of probabilities, `shape=(B, K)`, where `K` represents the number classes in our dataset.
# In our case `K=10`.
#
# We will first try to solve this problem using a fully connected deep network (like your DeepNet from lab 2), sometimes called a Multi-Layer Perceptron (MLP).
# Implement an `MLP` below (don't forget to use `nn.Sequential`, `nn.Linear`, `nn.ReLU`).
# Because `nn.Linear` expects tensors of shape `(B, Z)`, where `Z` is the input feature size, we need to flatten our images. Use the `.view()` function to reshape `x.shape=(B, C, H, W)` into `x.shape=(B, Z)`, where `Z=C*H*W`.

# %%
class MLP(nn.Module):
    def __init__(self, in_features, out_features, hidden_size):
        super(MLP, self).__init__()

        self.network = nn.Sequential(
            nn.Linear(in_features, hidden_size),  #first hidden layer
            nn.ReLU(),                           #activation function
            nn.Linear(hidden_size, out_features)  #output layer
        )

    def forward(self, x):
        # Flatten
        x = x.view(x.size(0), -1)
        return self.network(x)

# %% [markdown]
# Because we are doing classification, we need to use a different loss function that MSE; cross entropy loss is a good choice and is a common loss function for classification.

# %% [markdown]
# ---
#
# # Softmax and CrossEntropy
#
# The cross entropy (CE) function is $CE(p, q) = - \sum p(x) \log q(x)$, where $p$ and $q$ are probability functions ($p$ is the target probabilities and $q$ is the predicted probabilities) and in our case $x$ represents a class.
#
# $p$ represents the target distribution, the true class distribution, which means it is a one-hot vector $p_c$, where $c$ represents the index of the class:
# $$p_i = \begin{cases}
# 1, & \textrm{if } i = c \\
# 0, & \textrm{if } i \not = c \\
# \end{cases}$$
#
# Then $CE(p, q) = - \sum_i p_i \log q_i$ will become $CE(p, q) = - p_c \log q_c$, because $p_{i \not = c} = 0$, which is further reduced to $CE(p, q) = - \log q_c$, since $p_c = 1$. In other words, cross entropy loss for classification is the negative log of the predicted probability of the correct class.
#
# Therefore, $p$ is never passed into `F.cross_entropy_loss()`, instead you pass in $q$ you predicted distribution and $c$ the index of the correct class.
#
# Implement `prenormalized_cross_entropy_loss` below. $q$ is assumed to be a normalized probability distribution.
#
# *Note: Do **not** use a for loop. You can index into a tensor with array slicing (hint: You will need to use `torch.arange()` for the 0th dimension of `q`)*

# %%
def prenormalized_cross_entropy_loss(q, c):
  correct_class_probs = q[torch.arange(q.size(0)), c]
  loss = -torch.log(correct_class_probs)
  return loss.mean()

# %% [markdown]
# Validate your function below.

# %%
def test_prenormalized_cross_entropy_loss():
    q = torch.tensor([[.1, .5, .4],
                      [.2, .2, .6],
                      [.3, .3, .3]])
    c = torch.tensor([2, 0, 1])
    assert torch.allclose(prenormalized_cross_entropy_loss(q, c), torch.tensor(1.2432), atol=1e-4)

test_prenormalized_cross_entropy_loss()

# %% [markdown]
# This assumed that `q` was a probability distribution, but usually neural networks output logits $l$, which are unnormalized probabilities.
# One way we could normalize our logits $l$ into probabilities $q$ is to divide $l$ by the sum of logits $q_i = \frac{l_i}{\sum_j l_j}$, but that doesn't work if $l_i$ is negative.
# The softmax, which exponentiates the $logit$, $q_i = \frac{e^{l_i}}{\sum_j e^{l_j}}$, before dividing by the sum of exponentiated logits removes the issues of negativity (there are other good reasons for using softmax, such as numerical stability).
#
# However, applying `q = softmax(l)` to `prenormalized_cross_entropy_loss(q, c)` can still be numerically unstable.
# Luckily, we can simplify our function:
# $$\begin{align}
# CE(l, c) &= - \log \frac{e^{l_c}}{\sum_j e^{l_j}} \\
# &= - (\log e^{l_c} - \log \sum_j e^{l_j}) \\
# &= - (l_c - \log \sum_j e^{l_j}) \\
# &= - l_c + \log \sum_j e^{l_j}
# \end{align}$$
#
# While you could implement $\log \sum_j e^{l_j}$, you should use `torch.logsumexp()` which will exponentiate, sum, and then log your logits, but in a more numerically stable way.
# Implement `cross_entropy_loss()` below.
# You can validate it works by comparing it with the output of `F.cross_entropy()`.
#
# *Note: Do **not** use a for loop*

# %%
def cross_entropy_loss(logits, c):
    correct_class_logits = logits[torch.arange(logits.size(0)), c]

    logsumexp_logits = torch.logsumexp(logits, dim=1)

    loss = -correct_class_logits + logsumexp_logits

    return loss.mean()

# %%
#logits --> unormalized
logits = torch.tensor([[1.0, 0.5, 0.4],
                       [2.0, 0.2, 0.6],
                       [0.3, 0.3, 0.3]])

#correct class indices
c = torch.tensor([2, 0, 1])

custom_loss = cross_entropy_loss(logits, c)
built_in_loss = F.cross_entropy(logits, c)

print(f"Custom Loss: {custom_loss.item()}")
print(f"Built-in Loss: {built_in_loss.item()}")
# Out:
# Custom Loss: 0.9371650815010071
# Built-in Loss: 0.9371650815010071

# %% [markdown]
# It is hard to tell how well a model is performing just from its cross entropy loss, so create a `get_accuracy()` function to measure accuracy.
# `get_accuracy()` takes in a `y_hat` and `y`, where `y_hat` contains the predicted logits (unnormalized probabilities) for some images `x` and `y` are the labels.
# You can get the predicted label from `y_hat`, by using the `torch.argmax()` function.
#
# *Note: Do **not** use a for loop.*

# %%
def get_accuracy(y_hat, y):
  predicted_labels = torch.argmax(y_hat, dim=1)

  # compare
  correct_predictions = (predicted_labels == y)

  accuracy = correct_predictions.float().mean()

  return accuracy.item()

# %% [markdown]
# ## Validation and Training

# %% [markdown]
# To see how well training is going, implement a `validation()` function to compute the average loss and accuracy over all instances in the `val_loader`.
# This function will look very similar to a basic training loop, but without any optimization, e.g. no `loss.backward()` or `optimizer.step()`.
# To speed up the process use `torch.no_grad()` to keep PyTorch from building the computation graph.
# You can use `torch.no_grad()` either as a decorator:
# ```python
# @torch.no_grad()
# def fn():
#     ...
# ```
# or as a context manager:
# ```python
# def fn():
#     with torch.no_grad():
#         ...
# ```
#
# *Remember you can use `.item()` on a tensor with one element to convert it into a float/int.*

# %%
def validation(net, val_loader):
  # TODO: Return the network's average loss and accuracy on the val loader
  # make sure no gradient computations occur
  net.eval()  # Put the model in evaluation mode
  total_loss = 0.0
  total_correct = 0
  total_samples = 0

  with torch.no_grad():
    for x, y in val_loader:
      x, y = x.to(device), y.to(device)

      y_hat = net(x)

      # compute the loss
      loss = cross_entropy_loss(y_hat, y)
      total_loss += loss.item() * x.size(0)

      # accuracy
      accuracy = get_accuracy(y_hat, y)
      total_correct += accuracy * x.size(0)

      total_samples += x.size(0)  # keep track of number of samples

  # average loss and accuracy over the validation set
  avg_loss = total_loss / total_samples
  avg_accuracy = total_correct / total_samples

  return avg_loss, avg_accuracy

# %% [markdown]
# Now implement the `train()` function.
# This will look similar to the `train()` you implemented in lab 2, but now you will also store training accuracies, and at every `log_val_interval` you will call `validation` and store the validation loss and accuracy.

# %%
def train(net, train_loader, val_loader, optimizer, n_optimization_steps, log_val_interval):
  # keep track of training and validation
  train_losses = []
  val_losses = []
  train_accuracies = []
  val_accuracies = []

  net.to(device)  # move the network to the device

  # put network in training mode
  net.train()

  # initialize batch iterator for train_loader
  train_loader_iter = iter(train_loader)

  for step in range(n_optimization_steps):
      # get the next batch from train_loader
      try:
        x, y = next(train_loader_iter)
      except StopIteration:
        # if we run out of batches, reset the iterator
        train_loader_iter = iter(train_loader)
        x, y = next(train_loader_iter)

      # move data to device
      x, y = x.to(device), y.to(device)

      # forward pass: compute predictions
      y_hat = net(x)

      # compute cross entroy loss
      loss = cross_entropy_loss(y_hat, y)

      # zero out previous gradients
      optimizer.zero_grad()

      # backprop the gradients
      loss.backward()

      # update the network parameters
      optimizer.step()

      # keep track of the training loss
      train_losses.append(loss.item())

      # track training accuracy
      accuracy = get_accuracy(y_hat, y)
      train_accuracies.append(accuracy)

      # every log_val_interval steps, get validation and log metrics
      if (step + 1) % log_val_interval == 0:
        avg_val_loss, val_accuracy = validation(net, val_loader)
        val_losses.append(avg_val_loss)
        val_accuracies.append(val_accuracy)

        print(f"Step {step + 1}/{n_optimization_steps},"
              f"Train Loss: {loss.item()},"
              f"Train Accuracy: {accuracy},"
              f"Val Loss: {avg_val_loss},"
              f"Val Accuracy: {val_accuracy}")

  return train_losses, train_accuracies, val_losses, val_accuracies

# %% [markdown]
# Now train an `MLP` on `MNIST`. To speed up training use the `torch.optim.Adam` optimizer instead of `torch.optim.SGD`.
#
# *Note: Don't forget to put your network on `device`.*

# %%
# TODO: Set torch seed for reproducibility
torch.manual_seed(0)

# TODO: Initialize your MLP, called net
net = MLP(in_features=28*28, hidden_size=64, out_features=10)

# TODO: Create an Adam optimizer (lr=.001 works well)
optimizer = torch.optim.Adam(net.parameters(), lr=0.001)

# TODO: Train your MLP for 2000 steps and set log_val_interval=50
train_losses, train_accuracies, val_losses, val_accuracies = train(net, train_loader, val_loader, optimizer, 2000, 50)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Step 50/2000,Train Loss: 1.1660737991333008,Train Accuracy: 0.6875,Val Loss: 1.0264464360237122,Val Accuracy: 0.7991
# Step 100/2000,Train Loss: 0.3677011728286743,Train Accuracy: 0.96875,Val Loss: 0.6011152903079987,Val Accuracy: 0.8534
# Step 150/2000,Train Loss: 0.4593290686607361,Train Accuracy: 0.875,Val Loss: 0.46944663870334624,Val Accuracy: 0.8831
# Step 200/2000,Train Loss: 0.3949820399284363,Train Accuracy: 0.90625,Val Loss: 0.4029125220298767,Val Accuracy: 0.8975
# Step 250/2000,Train Loss: 0.4593059718608856,Train Accuracy: 0.875,Val Loss: 0.3756745947599411,Val Accuracy: 0.8982
# Step 300/2000,Train Loss: 0.4157590866088867,Train Accuracy: 0.84375,Val Loss: 0.34957896859645843,Val Accuracy: 0.9024
# Step 350/2000,Train Loss: 0.2602337598800659,Train Accuracy: 0.96875,Val Loss: 0.33447469482421877,Val Accuracy: 0.9051
# Step 400/2000,Train Loss: 0.15998795628547668,Train Accuracy: 0.96875,Val Loss: 0.3208902023077011,Val Accuracy: 0.9125
# Step 450/2000,Train Loss: 0.22544030845165253,Train Accuracy: 0.9375,Val Loss: 0.3073571550965309,Val Accuracy: 0.915
# Step 500/2000,Train Loss: 0.7832610011100769,Train Accuracy: 0.8125,Val Loss: 0.3077581034898758,Val Accuracy: 0.9087
# Step 550/2000,Train Loss: 0.23218561708927155,Train Accuracy: 0.9375,Val Loss: 0.2920142580032349,Val Accuracy: 0.9176
# Step 600/2000,Train Loss: 0.4200648069381714,Train Accuracy: 0.9375,Val Loss: 0.30200679116249085,Val Accuracy: 0.916
# Step 650/2000,Train Loss: 0.34939947724342346,Train Accuracy: 0.90625,Val Loss: 0.29928010618686673,Val Accuracy: 0.9131
# Step 700/2000,Train Loss: 0.21720923483371735,Train Accuracy: 0.9375,Val Loss: 0.2799238361120224,Val Accuracy: 0.9175
# Step 750/2000,Train Loss: 0.42589208483695984,Train Accuracy: 0.84375,Val Loss: 0.27536546096801756,Val Accuracy: 0.9187
# Step 800/2000,Train Loss: 0.17853760719299316,Train Accuracy: 0.96875,Val Loss: 0.2726440910100937,Val Accuracy: 0.9239
# Step 850/2000,Train Loss: 0.31305843591690063,Train Accuracy: 0.875,Val Loss: 0.26245331158638,Val Accuracy: 0.9257
# Step 900/2000,Train Loss: 0.14619599282741547,Train Accuracy: 1.0,Val Loss: 0.2682463292121887,Val Accuracy: 0.9215
# Step 950/2000,Train Loss: 0.3472038507461548,Train Accuracy: 0.90625,Val Loss: 0.2552222743868828,Val Accuracy: 0.9238
# Step 1000/2000,Train Loss: 0.3085295557975769,Train Accuracy: 0.90625,Val Loss: 0.26773003191947936,Val Accuracy: 0.9235
# Step 1050/2000,Train Loss: 0.20845293998718262,Train Accuracy: 0.96875,Val Loss: 0.24728548476696013,Val Accuracy: 0.9269
# Step 1100/2000,Train Loss: 0.3469565808773041,Train Accuracy: 0.875,Val Loss: 0.238077379322052,Val Accuracy: 0.9308
# Step 1150/2000,Train Loss: 0.09791168570518494,Train Accuracy: 0.96875,Val Loss: 0.2376243686199188,Val Accuracy: 0.9308
# Step 1200/2000,Train Loss: 0.1723460555076599,Train Accuracy: 0.96875,Val Loss: 0.24362186770439148,Val Accuracy: 0.9292
# Step 1250/2000,Train Loss: 0.2982376217842102,Train Accuracy: 0.8125,Val Loss: 0.23087152240276337,Val Accuracy: 0.9343
# Step 1300/2000,Train Loss: 0.30645471811294556,Train Accuracy: 0.96875,Val Loss: 0.22836809619665147,Val Accuracy: 0.935
# Step 1350/2000,Train Loss: 0.4608343839645386,Train Accuracy: 0.90625,Val Loss: 0.2300218039393425,Val Accuracy: 0.9355
# Step 1400/2000,Train Loss: 0.14196476340293884,Train Accuracy: 0.9375,Val Loss: 0.22827939933538438,Val Accuracy: 0.9343
# Step 1450/2000,Train Loss: 0.0889475867152214,Train Accuracy: 1.0,Val Loss: 0.22628624718189239,Val Accuracy: 0.9359
# Step 1500/2000,Train Loss: 0.2594468891620636,Train Accuracy: 0.875,Val Loss: 0.21472175285816192,Val Accuracy: 0.9392
# Step 1550/2000,Train Loss: 0.33676525950431824,Train Accuracy: 0.90625,Val Loss: 0.22267480882406235,Val Accuracy: 0.9373
# Step 1600/2000,Train Loss: 0.45055505633354187,Train Accuracy: 0.84375,Val Loss: 0.21602451312541962,Val Accuracy: 0.9371
# Step 1650/2000,Train Loss: 0.20321285724639893,Train Accuracy: 0.90625,Val Loss: 0.21045812509059905,Val Accuracy: 0.9399
# Step 1700/2000,Train Loss: 0.19738876819610596,Train Accuracy: 0.9375,Val Loss: 0.21057302570343017,Val Accuracy: 0.9364
# Step 1750/2000,Train Loss: 0.18804188072681427,Train Accuracy: 0.9375,Val Loss: 0.2031268161058426,Val Accuracy: 0.9396
# Step 1800/2000,Train Loss: 0.1569570153951645,Train Accuracy: 1.0,Val Loss: 0.19710556735992432,Val Accuracy: 0.9431
# Step 1850/2000,Train Loss: 0.36586886644363403,Train Accuracy: 0.875,Val Loss: 0.1955280776143074,Val Accuracy: 0.9428
# Step 1900/2000,Train Loss: 0.03813144564628601,Train Accuracy: 1.0,Val Loss: 0.19295026450157166,Val Accuracy: 0.9422
# Step 1950/2000,Train Loss: 0.28877735137939453,Train Accuracy: 0.8125,Val Loss: 0.18810403678417206,Val Accuracy: 0.9452
# Step 2000/2000,Train Loss: 0.1836332529783249,Train Accuracy: 0.9375,Val Loss: 0.18688343235254287,Val Accuracy: 0.9459

# %% [markdown]
# Now plot your training and validation loss on the same plot and plot your training and validation accuracies on the same plot.
# Properly set your x- and y-axis labels and create a legend to make your plot legible.
#
# *Note: that you can specify the x-values for each point by calling `plt.plot(x, y)` instead of `plt.plot(y)`. Since you store validation every 50 steps, you'll need to use `torch.arange` to get the proper x-values to align the validation results to the training results.*

# %%
log_val_interval = 50

# create x-values for training (all steps)
train_steps = torch.arange(len(train_losses))

# create x-values for validation --> only every log_val_interval step
val_steps = torch.arange(0, len(train_losses), log_val_interval)

# plot training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(train_steps, train_losses, label='Training Loss')
plt.plot(val_steps, val_losses, label='Validation Loss')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(train_steps, train_accuracies, label='Training Accuracy')
plt.plot(val_steps, val_accuracies, label='Validation Accuracy')
plt.xlabel('Steps')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ___
#
# # Convolution Networks
#
# Now we will create a convolution network.
# When we were dealing with an `MLP` we used fully-connected `nn.Linear` layers.
# In a convolution network we use `nn.Conv2d` layers.
# `nn.Linear` maps tensors of shape `(B, F_in) -> (B, F_out)`.
# `nn.Conv2d` maps tensors of shape `(B, C_in, H_in, W_in) -> (B, C_out, H_out, W_out)`, where `C_in` represents our input channels and `C_out` represents our output channels.
# You decide what `C_out` should be when you initialize.
# The mapping that
#
# If we had a batch of `img` tensors with shape `(B, 3, 8, 8)` and we wanted it to become `(B, 6, 4, 4)` we could create a convolution layer:
# ```python
# conv_layer = nn.Conv2d(in_channels=3,  # Our 'C_in' which is 3
#                        out_channels=6, # Our desired 'C_out'
#                        kernel_size=2,  # One way to make an 8x8 image become a 2x2 image is to have the kernel be 2x2,
#                        padding=0,      #    with zero padding,
#                        stride=2,       #    and a stride of 2.
#                       )
# ```
# Validate this is true below by creating `conv_prac()` function, which creates a random tensor with shape `(B, 3, 8, 8)`, passes it through `conv_layer`, and prints out the resulting shape.
#
# *Note: `kernel_size`, `padding`, and `stride` can all be tuples in case you want different (height, width) parameters, e.g. `kernel=(kernel_height, kernel_width)`.*

# %%
def conv_prac():

  # convolutional layer
  conv_layer = nn.Conv2d(
      in_channels=3,   # 3 input channels
      out_channels=6,  # 6 output channels
      kernel_size=2,   # 2x2 convolution kernel
      padding=0,       # No padding
      stride=2         # Stride of 2
  )

  img = torch.randn(1, 3, 8, 8) # batch of 1, 3 channels, 8x8 size

  output = conv_layer(img)

  print(f"Output shape after conv layer: {output.shape}")

conv_prac()
# Out:
# Output shape after conv layer: torch.Size([1, 6, 4, 4])

# %% [markdown]
# ___
#
# ### Quiz
# Test your knowledge of how convolution layers affect the shape of outputs by answering the following quiz questions.
#
#
# *Using a Kernel size of 3×3 what should the settings of your 2d convolution be that results in the following mappings (first answer given to you)*
#
# * (c=3, h=10, w=10) ⇒ (c=10, h=8, w=8) : **(out_channels=10, kernel_size=(3, 3), padding=(0, 0))**
# * (c=3, h=10, w=10) ⇒ (c=22, h=10, w=10) : **(out_channels=22, kernel_size=(3, 3), padding=(1, 1))**
# * (c=3, h=10, w=10) ⇒ (c=65, h=12, w=12) : **(out_channels=65, kernel_size=(3, 3), padding=(2, 2))**
# * (c=3, h=10, w=10) ⇒ (c=7, h=20, w=20) : **(out_channels=7, kernel_size=(3, 3), padding=(6, 6))**
#
# *Using a Kernel size of 5×5:*
#
# * (c=3, h=10, w=10) ⇒ (c=10, h=8, w=8) : (out_channels=10, kernel_size=(5, 5), padding=(1, 1))
# * (c=3, h=10, w=10) ⇒ (c=100, h=10, w=10) : **(out_channels=100, kernel_size=(5, 5), padding=(2, 2))**
# * (c=3, h=10, w=10) ⇒ (c=23, h=12, w=12) : **(out_channels=23, kernel_size=(5, 5), padding=(3, 3))**
# * (c=3, h=10, w=10) ⇒ (c=5, h=24, w=24) : **(out_channels=5, kernel_size=(5, 5), padding=(9, 9))**
#
# *Using Kernel size of 5×3:*
#
# * (c=3, h=10, w=10) ⇒ (c=10, h=8, w=8) : **(out_channels=10, kernel_size=(5, 3), padding=(1, 0))**
# * (c=3, h=10, w=10) ⇒ (c=100, h=10, w=10) : **(out_channels=100, kernel_size=(5, 3), padding=(6, 6))**
# * (c=3, h=10, w=10) ⇒ (c=23, h=12, w=12) : **(out_channels=23, kernel_size=(5, 3), padding=(2, 1))**
# * (c=3, h=10, w=10) ⇒ (c=5, h=24, w=24) : **(out_channels=5, kernel_size=(5, 3), padding=(9, 7))**
#
# *Determine the kernel that requires the smallest padding size to make the following mappings possible:*
#
# * (c=3, h=10, w=10) ⇒ (c=10, h=9, w=7) : **kernal size = (2,4), padding = (0,0) **
# * (c=3, h=10, w=10) ⇒ (c=22, h=10, w=10) : **kernal size = (3,3)padding = (1,1)**

# %% [markdown]
# ## ConvNet
#
# Now create a convolution network `ConvNet` that inherits `nn.Module`.
# The network should have 3 convolution layers (each layer should have 16 output channels):
# 1. Conv Layer 1 should have a 6x6 kernel, no padding, and a stride of 2.
# 2. Conv Layer 2 should have a 4x4 kernel, no padding, and a stride of 2.
# 3. Conv Layer 3 should have a 3x3 kernel, no padding, and a stride of 1.
#
# The output of these layers should be a 3x3 image with 16 channels.
# You should flatten the image (you can use `.view()`, `torch.flatten()`, or `nn.Flatten()`) and then pass it through 2 linear layers:
# 1. Linear Layer 1 should take the flattened image and map it to a vector with 16 features.
# 2. Linear Layer 2 should map its vector to logits.
#
# Do not forget to add nonlinearities between the layers (do not add them to the last layer).

# %%
class ConvNet(nn.Module):
    def __init__(self):
      super(ConvNet, self).__init__()

      self.conv_layer1 = nn.Conv2d(
        in_channels=1,   # 1 input channel because grayscale images
        out_channels=16,  # 16 output channels
        kernel_size=6,   # 6x6 convolution kernel
        padding=0,       # No padding
        stride=2         # Stride of 2
      )

      self.conv_layer2 = nn.Conv2d(
        in_channels=16,   # 3 input channels
        out_channels=16,  # 16 output channels
        kernel_size=4,   # 4x4 convolution kernel
        padding=0,       # No padding
        stride=2        # Stride of 2
      )

      self.conv_layer3 = nn.Conv2d(
        in_channels=16,   # 3 input channels
        out_channels=16,  # 16 output channels
        kernel_size=3,   # 3x3 convolution kernel
        padding=0,       # No padding
        stride=1         # Stride of 1
      )


      self.flatten = nn.Flatten()

      #linear layers
      self.linear_layer1 = nn.Linear(16 * 3 * 3, 16)  # map from flattened 16*3*3 vector to 16 features
      self.linear_layer2 = nn.Linear(16, 10)  # map from 16 features to 10 output classes (logits)


    def forward(self, x):
        x = F.relu(self.conv_layer1(x))
        x = F.relu(self.conv_layer2(x))
        x = F.relu(self.conv_layer3(x))

        # Flatten the output
        x = self.flatten(x)

        # Forward pass through fully connected layers with ReLU
        x = F.relu(self.linear_layer1(x))
        x = self.linear_layer2(x)  # final logits

        return x

# %% [markdown]
# Train you convolution network below.

# %%
# TODO: Set seed for reproducibility
torch.manual_seed(0)
# TODO: Initalize your ConvNet, called 'conv_net'
conv_net = ConvNet()

# TODO: Create an Adam optimizer (lr=.001 works well)
optimizer = torch.optim.Adam(conv_net.parameters(), lr=0.001)

# TODO: Train your ConvNet for 2000 steps and set log_val_interval=50
train_losses, train_accuracies, val_losses, val_accuracies = train(conv_net,
                                                                   train_loader,
                                                                   val_loader,
                                                                   optimizer,
                                                                   2000, 50)
# Out:
# Step 50/2000,Train Loss: 1.7374268770217896,Train Accuracy: 0.40625,Val Loss: 1.670024914932251,Val Accuracy: 0.4929
# Step 100/2000,Train Loss: 0.7929162383079529,Train Accuracy: 0.8125,Val Loss: 0.7238698493003846,Val Accuracy: 0.761
# Step 150/2000,Train Loss: 0.7016831040382385,Train Accuracy: 0.78125,Val Loss: 0.5310467538595199,Val Accuracy: 0.8313
# Step 200/2000,Train Loss: 0.6258931756019592,Train Accuracy: 0.84375,Val Loss: 0.5139684557199479,Val Accuracy: 0.842
# Step 250/2000,Train Loss: 0.24489082396030426,Train Accuracy: 0.875,Val Loss: 0.42869498035907744,Val Accuracy: 0.8681
# Step 300/2000,Train Loss: 0.3117322325706482,Train Accuracy: 0.90625,Val Loss: 0.3774520054578781,Val Accuracy: 0.8864
# Step 350/2000,Train Loss: 0.23700858652591705,Train Accuracy: 0.9375,Val Loss: 0.35371566936969756,Val Accuracy: 0.8897
# Step 400/2000,Train Loss: 0.33947688341140747,Train Accuracy: 0.875,Val Loss: 0.31090700240135194,Val Accuracy: 0.9061
# Step 450/2000,Train Loss: 0.42136871814727783,Train Accuracy: 0.84375,Val Loss: 0.3001545652627945,Val Accuracy: 0.9084
# Step 500/2000,Train Loss: 0.24666695296764374,Train Accuracy: 0.9375,Val Loss: 0.32001002993583677,Val Accuracy: 0.9014
# Step 550/2000,Train Loss: 0.4695199429988861,Train Accuracy: 0.875,Val Loss: 0.26770718109607694,Val Accuracy: 0.9188
# Step 600/2000,Train Loss: 0.5545946359634399,Train Accuracy: 0.875,Val Loss: 0.24825468709468843,Val Accuracy: 0.9244
# Step 650/2000,Train Loss: 0.3471871018409729,Train Accuracy: 0.90625,Val Loss: 0.2546692556858063,Val Accuracy: 0.9213
# Step 700/2000,Train Loss: 0.0964391678571701,Train Accuracy: 1.0,Val Loss: 0.23804605312347413,Val Accuracy: 0.9291
# Step 750/2000,Train Loss: 0.16270604729652405,Train Accuracy: 0.96875,Val Loss: 0.23187409636974335,Val Accuracy: 0.9295
# Step 800/2000,Train Loss: 0.5056301355361938,Train Accuracy: 0.84375,Val Loss: 0.22477845342159272,Val Accuracy: 0.9306
# Step 850/2000,Train Loss: 0.04168941080570221,Train Accuracy: 1.0,Val Loss: 0.22382759563922883,Val Accuracy: 0.9315
# Step 900/2000,Train Loss: 0.2976093292236328,Train Accuracy: 0.90625,Val Loss: 0.24728106784820555,Val Accuracy: 0.9282
# Step 950/2000,Train Loss: 0.10473719984292984,Train Accuracy: 0.96875,Val Loss: 0.18787501192092895,Val Accuracy: 0.9446
# Step 1000/2000,Train Loss: 0.36205458641052246,Train Accuracy: 0.90625,Val Loss: 0.2092717593431473,Val Accuracy: 0.9393
# Step 1050/2000,Train Loss: 0.10939063131809235,Train Accuracy: 0.96875,Val Loss: 0.19162105205059052,Val Accuracy: 0.9435
# Step 1100/2000,Train Loss: 0.13600535690784454,Train Accuracy: 0.9375,Val Loss: 0.1788380294561386,Val Accuracy: 0.9455
# Step 1150/2000,Train Loss: 0.26962873339653015,Train Accuracy: 0.875,Val Loss: 0.1924122316122055,Val Accuracy: 0.9432
# Step 1200/2000,Train Loss: 0.08061079680919647,Train Accuracy: 0.96875,Val Loss: 0.16828088717460632,Val Accuracy: 0.9502
# Step 1250/2000,Train Loss: 0.056413620710372925,Train Accuracy: 1.0,Val Loss: 0.16764704675674438,Val Accuracy: 0.9498
# Step 1300/2000,Train Loss: 0.08549942076206207,Train Accuracy: 0.96875,Val Loss: 0.18358248174190522,Val Accuracy: 0.9435
# Step 1350/2000,Train Loss: 0.19275707006454468,Train Accuracy: 0.96875,Val Loss: 0.16271219506263732,Val Accuracy: 0.9496
# Step 1400/2000,Train Loss: 0.05447246879339218,Train Accuracy: 1.0,Val Loss: 0.1643551398873329,Val Accuracy: 0.9478
# Step 1450/2000,Train Loss: 0.06370601803064346,Train Accuracy: 1.0,Val Loss: 0.15773521580696107,Val Accuracy: 0.9548
# Step 1500/2000,Train Loss: 0.03318195044994354,Train Accuracy: 1.0,Val Loss: 0.15688534603118898,Val Accuracy: 0.9544
# Step 1550/2000,Train Loss: 0.19246357679367065,Train Accuracy: 0.9375,Val Loss: 0.16136835224628449,Val Accuracy: 0.9492
# Step 1600/2000,Train Loss: 0.061103224754333496,Train Accuracy: 0.96875,Val Loss: 0.14963618786334992,Val Accuracy: 0.9541
# Step 1650/2000,Train Loss: 0.06439918279647827,Train Accuracy: 1.0,Val Loss: 0.14667237772941588,Val Accuracy: 0.9555
# Step 1700/2000,Train Loss: 0.05069119483232498,Train Accuracy: 0.96875,Val Loss: 0.1604688063979149,Val Accuracy: 0.9512
# Step 1750/2000,Train Loss: 0.24904592335224152,Train Accuracy: 0.90625,Val Loss: 0.1385366313457489,Val Accuracy: 0.9574
# Step 1800/2000,Train Loss: 0.05185318738222122,Train Accuracy: 1.0,Val Loss: 0.13558748126029968,Val Accuracy: 0.9576
# Step 1850/2000,Train Loss: 0.24620255827903748,Train Accuracy: 0.875,Val Loss: 0.12678509814739228,Val Accuracy: 0.9605
# Step 1900/2000,Train Loss: 0.1965010166168213,Train Accuracy: 0.96875,Val Loss: 0.11741591875553131,Val Accuracy: 0.9644
# Step 1950/2000,Train Loss: 0.10580431669950485,Train Accuracy: 0.96875,Val Loss: 0.12336116238832474,Val Accuracy: 0.9642
# Step 2000/2000,Train Loss: 0.15191525220870972,Train Accuracy: 0.96875,Val Loss: 0.13369198979139327,Val Accuracy: 0.9593

# %% [markdown]
# Now plot your training and validation loss on the same plot and plot your training and validation accuracies on the same plot.

# %%
log_val_interval = 50

# create x-values for training (all steps)
train_steps = torch.arange(len(train_losses))

# create x-values for validation --> only every log_val_interval step
val_steps = torch.arange(0, len(train_losses), log_val_interval)

# plot training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(train_steps, train_losses, label='Training Loss')
plt.plot(val_steps, val_losses, label='Validation Loss')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(train_steps, train_accuracies, label='Training Accuracy')
plt.plot(val_steps, val_accuracies, label='Validation Accuracy')
plt.xlabel('Steps')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Create a function that outputs the number of parameters in a network.
# Remember you can call `.parameters()` to recursively retrieve the `Parameter`s in a `Module`.
# You could then use `.shape` to figure out the number of parameters in a `Parameter` or you could flatten the parameter and get its length.

# %%
def get_n_net_params(net):
  total_params = sum(param.numel() for param in net.parameters())
  return total_params

# %% [markdown]
# Print the number of parameters and the accuracy of your trained `MLP` and `ConvNet` networks and then write down below:
# - Which one is more accurate?
# - Which one is smaller?
#
# *Note: You can use `validation()` to get the accuracy of your network.*

# %%
def get_accuracy_of_network(net, val_loader):
    avg_loss, accuracy = validation(net, val_loader)
    return accuracy

# %%
# Get number of parameters for each network
mlp_params = get_n_net_params(net)
conv_net_params = get_n_net_params(conv_net)

# Get accuracy for each network
mlp_accuracy = get_accuracy_of_network(net, val_loader)
conv_net_accuracy = get_accuracy_of_network(conv_net, val_loader)

# Print the results
print(f"MLP Network: {mlp_params} parameters, Accuracy: {mlp_accuracy}")
print(f"ConvNet: {conv_net_params} parameters, Accuracy: {conv_net_accuracy}")
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# MLP Network: 50890 parameters, Accuracy: 0.9459
# ConvNet: 9514 parameters, Accuracy: 0.9593

# %% [markdown]
# ConvNet is both smaller and more accurate. Although we could argue if 1-2% is statistically significant
